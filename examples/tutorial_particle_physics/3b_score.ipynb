# %% [markdown]
# # MadMiner physics tutorial (part 3B)
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3A of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2A of this tutorial. If, instead of 2A, you have run part 2B, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Make sure you've run the first tutorial before executing this notebook!

# %%
import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ScoreEstimator

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
sampler = SampleAugmenter("data/lhe_data_shuffled.h5")
# sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 12:22 madminer.analysis.da INFO    Loading data from data/lhe_data_shuffled.h5
# 12:22 madminer.utils.inter ERROR   HDF5 file does not contain nuisance parameters information
# 12:22 madminer.utils.inter ERROR   HDF5 file does not contain finite difference information
# 12:22 madminer.utils.inter ERROR   HDF5 file does not contain systematic information
# 12:22 madminer.analysis.da INFO    Found 2 parameters
# 12:22 madminer.analysis.da INFO      0: CWL2 (LHA: dim6 2, Power: 2, Range: (-20.0, 20.0)Label: None)
# 12:22 madminer.analysis.da INFO      1: CPWL2 (LHA: dim6 5, Power: 2, Range: (-20.0, 20.0)Label: None)
# 12:22 madminer.analysis.da INFO    Did not find nuisance parameters
# 12:22 madminer.analysis.da INFO    Found 6 benchmarks
# 12:22 madminer.analysis.da INFO    Found 3 observables
# 12:22 madminer.analysis.da INFO    Found 120017 events
# 12:22 madminer.analysis.da INFO      49992 signal events sampled from benchmark sm
# 12:22 madminer.analysis.da INFO      10000 signal events sampled from benchmark w
# 12:22 madminer.analysis.da INFO      10000 signal events sampled from benchmark neg_w
# 12:22 madminer.analysis.da INFO      9999 signal events sampled from benchmark ww
# 12:22 madminer.analysis.da INFO      10000 signal events sampled from benchmark neg_ww
# 12:22 madminer.analysis.da INFO      0 signal events sampled from benchmark morphing_basis_vector_5
# 12:22 madminer.analysis.da INFO      30026 background events
# 12:22 madminer.analysis.da INFO    Found morphing setup with 6 components
# 12:22 madminer.analysis.da INFO    Did not find nuisance morphing setup

# %%
madminer.sampling.SampleAugmenter?
# Out:
# Object `madminer.sampling.SampleAugmenter` not found.

# %%
SampleAugmenter().sample_train_local

# %% [markdown]
# The relevant `SampleAugmenter` function for local score estimators is `extract_samples_train_local()`. As in part 3a of the tutorial, for the argument `theta` you can use the helper functions `sampling.benchmark()`, `sampling.benchmarks()`, `sampling.morphing_point()`, `sampling.morphing_points()`, and `sampling.random_morphing_points()`.

# %%
x, theta, t_xz, _ = sampler.sample_train_local(
    theta=sampling.benchmark("sm"),
    n_samples=500000,
    folder="./data/samples",
    filename="train_score",
)
# Out:
# 12:23 madminer.sampling.sa INFO    Extracting training sample for local score regression. Sampling and score evaluation according to sm
# 12:23 madminer.sampling.sa INFO    Starting sampling serially
# 12:23 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 12:23 madminer.sampling.sa INFO    Effective number of samples: mean 19317.697612313936, with individual thetas ranging from 19317.697612313936 to 19317.697612313936

# %% [markdown]
# We can use the same data as in part 3a, so you only have to execute this if you haven't gone through tutorial 3a:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark("sm"),
    n_samples=1000,
    folder="./data/samples",
    filename="test",
)
# Out:
# 12:23 madminer.sampling.sa INFO    Extracting evaluation sample. Sampling according to sm
# 12:23 madminer.sampling.sa INFO    Starting sampling serially
# 12:23 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 12:23 madminer.sampling.sa INFO    Effective number of samples: mean 6463.457553853645, with individual thetas ranging from 6463.4575538536465 to 6463.4575538536465

# %% [markdown]
# ## 2. Train score estimator

# %% [markdown]
# It's now time to build a neural network. Only this time, instead of the likelihood ratio itself, we will estimate the gradient of the log likelihood with respect to the theory parameters -- the score. To be precise, the output of the neural network is an estimate of the score at some reference parameter point, for instance the Standard Model. A neural network that estimates this "local" score can be used to calculate the Fisher information at that point. The estimated score can also be used as a machine learning version of Optimal Observables, and likelihoods can be estimated based on density estimation in the estimated score space. This method for likelihood ratio estimation is called SALLY, and there is a closely related version called SALLINO. Both are explained in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020).
#
# The central object for this is the `madminer.ml.ScoreEstimator` class:

# %%
estimator = ScoreEstimator(n_hidden=(30, 30))

# %%
estimator.train(
    method="sally",
    x="data/samples/x_train_score.npy",
    t_xz="data/samples/t_xz_train_score.npy",
)

estimator.save("models/sally")
# Out:
# 12:23 madminer.ml.score    INFO    Starting training
# 12:23 madminer.ml.score    INFO      Batch size:             128
# 12:23 madminer.ml.score    INFO      Optimizer:              amsgrad
# 12:23 madminer.ml.score    INFO      Epochs:                 50
# 12:23 madminer.ml.score    INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 12:23 madminer.ml.score    INFO      Validation split:       0.25
# 12:23 madminer.ml.score    INFO      Early stopping:         True
# 12:23 madminer.ml.score    INFO      Scale inputs:           True
# 12:23 madminer.ml.score    INFO      Shuffle labels          False
# 12:23 madminer.ml.score    INFO      Samples:                all
# 12:23 madminer.ml.score    INFO    Loading training data
# 12:23 madminer.utils.vario INFO      Loading data/samples/x_train_score.npy into RAM
# 12:23 madminer.utils.vario INFO      Loading data/samples/t_xz_train_score.npy into RAM
# 12:23 madminer.ml.score    INFO    Found 500000 samples with 2 parameters and 3 observables
# 12:23 madminer.ml.base     INFO    Setting up input rescaling
# 12:23 madminer.ml.score    INFO    Creating model
# 12:23 madminer.ml.score    INFO    Training model
# 12:23 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 12:23 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.04789 (mse_score:  0.048)
# 12:23 madminer.utils.ml.tr INFO                 val. loss   0.04411 (mse_score:  0.048)
# 12:24 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.04696 (mse_score:  0.047)
# 12:24 madminer.utils.ml.tr INFO                 val. loss   0.04318 (mse_score:  0.047)
# 12:24 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.04592 (mse_score:  0.046)
# 12:24 madminer.utils.ml.tr INFO                 val. loss   0.04212 (mse_score:  0.046)
# 12:25 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.04543 (mse_score:  0.045)
# 12:25 madminer.utils.ml.tr INFO                 val. loss   0.04199 (mse_score:  0.045)
# 12:25 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.04502 (mse_score:  0.045)
# 12:25 madminer.utils.ml.tr INFO                 val. loss   0.04154 (mse_score:  0.045)
# 12:25 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.04452 (mse_score:  0.045)
# 12:25 madminer.utils.ml.tr INFO                 val. loss   0.04149 (mse_score:  0.045)
# 12:26 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.04423 (mse_score:  0.044)
# 12:26 madminer.utils.ml.tr INFO                 val. loss   0.04201 (mse_score:  0.044)
# 12:26 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.04390 (mse_score:  0.044)
# 12:26 madminer.utils.ml.tr INFO                 val. loss   0.04094 (mse_score:  0.044)
# 12:26 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.04361 (mse_score:  0.044)
# 12:26 madminer.utils.ml.tr INFO                 val. loss   0.04059 (mse_score:  0.044)
# 12:27 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.04333 (mse_score:  0.043)
# 12:27 madminer.utils.ml.tr INFO                 val. loss   0.04042 (mse_score:  0.043)
# 12:27 madminer.utils.ml.tr INFO      Epoch  22: train loss  0.04305 (mse_score:  0.043)
# 12:27 madminer.utils.ml.tr INFO                 val. loss   0.04034 (mse_score:  0.043)
# 12:28 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.04282 (mse_score:  0.043)
# 12:28 madminer.utils.ml.tr INFO                 val. loss   0.04068 (mse_score:  0.043)
# 12:28 madminer.utils.ml.tr INFO      Epoch  26: train loss  0.04265 (mse_score:  0.043)
# 12:28 madminer.utils.ml.tr INFO                 val. loss   0.04010 (mse_score:  0.043)
# 12:28 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.04243 (mse_score:  0.042)
# 12:28 madminer.utils.ml.tr INFO                 val. loss   0.04036 (mse_score:  0.042)
# 12:29 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.04227 (mse_score:  0.042)
# 12:29 madminer.utils.ml.tr INFO                 val. loss   0.04010 (mse_score:  0.042)
# 12:29 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.04213 (mse_score:  0.042)
# 12:29 madminer.utils.ml.tr INFO                 val. loss   0.03999 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO      Epoch  34: train loss  0.04202 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO                 val. loss   0.04006 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.04191 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO                 val. loss   0.03985 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO      Epoch  38: train loss  0.04176 (mse_score:  0.042)
# 12:30 madminer.utils.ml.tr INFO                 val. loss   0.03972 (mse_score:  0.042)
# 12:31 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.04164 (mse_score:  0.042)
# 12:31 madminer.utils.ml.tr INFO                 val. loss   0.03984 (mse_score:  0.042)
# 12:31 madminer.utils.ml.tr INFO      Epoch  42: train loss  0.04155 (mse_score:  0.042)
# 12:31 madminer.utils.ml.tr INFO                 val. loss   0.03984 (mse_score:  0.042)
# 12:32 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.04146 (mse_score:  0.041)
# 12:32 madminer.utils.ml.tr INFO                 val. loss   0.03980 (mse_score:  0.041)
# 12:32 madminer.utils.ml.tr INFO      Epoch  46: train loss  0.04140 (mse_score:  0.041)
# 12:32 madminer.utils.ml.tr INFO                 val. loss   0.03976 (mse_score:  0.041)
# 12:33 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.04134 (mse_score:  0.041)
# 12:33 madminer.utils.ml.tr INFO                 val. loss   0.03970 (mse_score:  0.041)
# 12:33 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.04128 (mse_score:  0.041)
# 12:33 madminer.utils.ml.tr INFO                 val. loss   0.03967 (mse_score:  0.041)
# 12:33 madminer.utils.ml.tr INFO    Early stopping after epoch 49, with loss  0.03964 compared to final loss  0.03967
# 12:33 madminer.utils.ml.tr INFO    Training time spend on:
# 12:33 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 12:33 madminer.utils.ml.tr INFO                                   ALL:   0.17h
# 12:33 madminer.utils.ml.tr INFO                            check data:   0.00h
# 12:33 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 12:33 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 12:33 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 12:33 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 12:33 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 12:33 madminer.utils.ml.tr INFO                   load training batch:   0.07h
# 12:33 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 12:33 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.01h
# 12:33 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.01h
# 12:33 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.01h
# 12:33 madminer.utils.ml.tr INFO                 training forward pass:   0.02h
# 12:33 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 12:33 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 12:33 madminer.utils.ml.tr INFO                         opt: backward:   0.01h
# 12:33 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 12:33 madminer.utils.ml.tr INFO                             opt: step:   0.03h
# 12:33 madminer.utils.ml.tr INFO                        optimizer step:   0.04h
# 12:33 madminer.utils.ml.tr INFO                 load validation batch:   0.02h
# 12:33 madminer.utils.ml.tr INFO               validation forward pass:   0.01h
# 12:33 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 12:33 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 12:33 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 12:33 madminer.ml.base     INFO    Saving model to models/sally

# %% [markdown]
# ## 3. Evaluate score estimator

# %% [markdown]
# Let's evaluate the SM score on the test data

# %%
estimator.load("models/sally")

t_hat = estimator.evaluate_score(x="data/samples/x_test.npy")
# Out:
# 12:35 madminer.ml.base     INFO    Loading model from models/sally
# 12:35 madminer.utils.vario INFO      Loading data/samples/x_test.npy into RAM

# %% [markdown]
# Let's have a look at the estimated score and how it is related to the observables:

# %%
x = np.load("data/samples/x_test.npy")

fig = plt.figure(figsize=(10, 4))

for i in range(2):
    ax = plt.subplot(1, 2, i + 1)
    sc = plt.scatter(
        x[:, 0],
        x[:, 1],
        c=t_hat[:, i],
        s=25.0,
        cmap="BrBG",
        vmin=-0.025,
        vmax=+0.025,
    )

    cbar = plt.colorbar(sc)

    cbar.set_label(r"$\hat{t}_" + str(i) + r"(x | \theta_{ref})$")
    plt.xlabel(r"$p_{T,j1}$ [GeV]")
    plt.ylabel(r"$\Delta \phi_{jj}$")
    plt.xlim(10.0, 300.0)
    plt.ylim(-3.15, 3.15)

plt.tight_layout()
plt.show()
